# %% [markdown]
# <a href="https://colab.research.google.com/github/aditiadri/cnn/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

path = kagglehub.dataset_download("vipoooool/new-plant-diseases-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 2.70G/2.70G [00:18<00:00, 154MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2

# %%
import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt

# %%
valid='/root/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid'

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
    valid,
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
class_name = validation_set.class_names
print(class_name)
# Out:
# Found 17572 files belonging to 38 classes.
# ...

# %%
# %cd cnn
# Out:
# /content/cnn

# %%
# !ls
# Out:
# depositphotos_658323714-stock-photo-green-rice-field-morning.jpg  Untitled17.ipynb
# index.html							  Untitled19.ipynb
# style.css

# %%
import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt

# %%
cnn = tf.keras.models.load_model('/content/drive/MyDrive/Models/my_model.keras')

# %%
import tensorflow as tf

# Load the trained model
model_path = '/content/drive/MyDrive/my_model.keras'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/
# Out:
# MyDrive  Shareddrives

# %%
# !ls /content/drive/MyDrive/
# Out:
# '09 ClassBasic.gslides'
# '10 ClassAdvanced.gslides'
# '11 ClusBasic.gslides'
#  16acbb11-3a36-4f17-beb6-0651d2faf5ec.dwg-0001.jpg
#  1.gdoc
# '2017 DAA-SOL MID-REGULAR.gdoc'
# '2022 End Sem (Autumn).gdoc'
# '2024-25 BCN Sample Resume Format.gdoc'
# '210151213_AYUSH KUMAR.gdoc'
# '2105031_Sheet 5.pdf'
# '2105091 Chemistry lab (1).pdf'
#  2105091Sheet+ed.dwg.zip
#  24a68afe-c8b4-405a-85a1-76b8a81bd520.JPG
#  2.gdoc
# '3rd  Semester , B. Tech , Engineering Economics, HS-2002,  Autumn  Mid Sem  Examination  2019.gdoc'
#  4order.jpeg
# '5091ADITI PANDEY - Assignment-III (Critical Thinking)_2021-22.pdf'
# '5091ADITI PANDEY - Assignment_II_MATH-I(2021-22).pdf'
# '5091ADITI PANDEY - Data sheet. - Line chart 1.gsheet'
# '5091ADITI PANDEY - Data sheet. - Line chart 2.gsheet'
# '5091ADITI PANDEY - Subject verb agreement .gdoc'
# '5091_Maths assign3 (1).pdf'
#  7THSEM~2.PDF.gdoc
# 'Aadhar_Aditi Pandey '
#  AdCTR.docx
# 'Aditi Certificate (Participation).pdf'
# 'Aditi chem file.pdf'
# ...

# %%
model = tf.keras.models.load_model(model_path)

# Verify that it loaded successfully
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 126, 126, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 63, 63, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 63, 63, 64)          │          18,496 │
# ...

# %%
import kagglehub

path = kagglehub.dataset_download("vipoooool/new-plant-diseases-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 2.70G/2.70G [00:19<00:00, 148MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2

# %%
image_path = 'test/test/AppleCedarRust1.JPG'

# %%
apple_scab_dir = '/root/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2/new plant diseases dataset(augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___Apple_scab'

# %%
# !ls '/root/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2/test/test'
# Out:
# AppleCedarRust1.JPG  CornCommonRust3.JPG     TomatoEarlyBlight2.JPG  TomatoYellowCurlVirus1.JPG
# AppleCedarRust2.JPG  PotatoEarlyBlight1.JPG  TomatoEarlyBlight3.JPG  TomatoYellowCurlVirus2.JPG
# AppleCedarRust3.JPG  PotatoEarlyBlight2.JPG  TomatoEarlyBlight4.JPG  TomatoYellowCurlVirus3.JPG
# AppleCedarRust4.JPG  PotatoEarlyBlight3.JPG  TomatoEarlyBlight5.JPG  TomatoYellowCurlVirus4.JPG
# AppleScab1.JPG	     PotatoEarlyBlight4.JPG  TomatoEarlyBlight6.JPG  TomatoYellowCurlVirus5.JPG
# AppleScab2.JPG	     PotatoEarlyBlight5.JPG  TomatoHealthy1.JPG      TomatoYellowCurlVirus6.JPG
# AppleScab3.JPG	     PotatoHealthy1.JPG      TomatoHealthy2.JPG
# CornCommonRust1.JPG  PotatoHealthy2.JPG      TomatoHealthy3.JPG
# CornCommonRust2.JPG  TomatoEarlyBlight1.JPG  TomatoHealthy4.JPG

# %%
path='/root/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2/test/test/AppleCedarRust1.JPG'

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
img = Image.open(path)

# Display the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])  # Hide X-axis ticks
plt.yticks([])  # Hide Y-axis ticks
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(path,target_size=(128,128))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = model.predict(input_arr)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step

# %%
print(predictions)
# Out:
# [[1.35174439e-14 1.71553657e-12 1.00000000e+00 1.03183626e-18
#   5.85114260e-13 7.56321221e-12 7.86516931e-20 2.69316226e-13
#   4.58427572e-16 3.73364745e-17 1.25025007e-21 1.43866245e-12
#   2.79255778e-16 1.30439084e-14 1.24477766e-13 2.93731700e-13
#   3.21513717e-14 1.77599238e-16 1.36537639e-11 4.59052758e-14
#   1.99112098e-15 1.97130933e-18 1.04573872e-15 1.33394317e-15
#   3.56904901e-18 2.06643680e-16 2.10245621e-16 2.28112405e-16
#   1.87736759e-09 7.01888686e-11 1.68199427e-10 1.06637167e-16
#   1.29303609e-10 2.28327343e-17 8.36357286e-12 7.57704489e-12
#   6.21393111e-15 1.47233960e-14]]

# %%
result_index = np.argmax(predictions) #Return index of max element
print(result_index)
# Out:
# 2

# %%
class_name = [
    'AppleCedarRust', 'AppleCedarRust', 'AppleCedarRust', 'AppleCedarRust',
    'AppleScab', 'AppleScab', 'AppleScab',
    'CornCommonRust', 'CornCommonRust', 'CornCommonRust',
    'TomatoEarlyBlight', 'TomatoEarlyBlight', 'TomatoEarlyBlight', 'TomatoEarlyBlight',
    'TomatoYellowCurlVirus', 'TomatoYellowCurlVirus', 'TomatoYellowCurlVirus', 'TomatoYellowCurlVirus',
    'PotatoEarlyBlight', 'PotatoEarlyBlight', 'PotatoEarlyBlight', 'PotatoEarlyBlight', 'PotatoEarlyBlight',
    'PotatoHealthy', 'PotatoHealthy', 'PotatoHealthy', 'PotatoHealthy',
    'TomatoHealthy', 'TomatoHealthy', 'TomatoHealthy', 'TomatoHealthy', 'TomatoHealthy'
]

# %%
model_prediction = class_name[result_index]
plt.imshow(img)
plt.title(f"Disease Name: {model_prediction}")
plt.xticks([])
plt.yticks([])
plt.show()
